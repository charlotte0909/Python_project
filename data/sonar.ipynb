# %%
import pickle as pkl
import numpy as np
import random
def load_pkl(file_name):
    with open(file_name, 'rb') as f:
        data = pkl.load(f)
    return data

# %%
sonar_data = load_pkl("sonar_data.pkl")

# %%
mines = sonar_data['m']
dataset = []
for mine in mines:
    dataset.append([mine, 1])

rocks = sonar_data['r']
for rock in rocks:
    dataset.append([rock, -1])

random.shuffle(dataset)
len(dataset[0][0])
# Out:
# 60

# %%
import numpy as np
import random

def save_pkl(file_name, data):
            with open(file_name, 'wb') as f:
                pkl.dump(data, f)

class Neuron:

    def __init__(self, dimension=1, weights=None, bias=None, activation=(lambda x: x), predict=(lambda x: x)):
        self._dim = dimension
        self.w = weights or np.array([random.random()*(-1)**random.randint(0, 1) for _ in range(self._dim)])
        self.w = np.array([float(w) for w in self.w])
        self.b = bias if bias is not None else random.random()*(-1)**random.randint(0, 1)
        self.b = float(self.b)
        self._a = activation
        self.predict = predict.__get__(self)

    def __str__(self):
        return "Simple cell neuron\n\
        \tInput dimension: %d\n\
        \tBias: %f\n\
        \tWeights: %s\n\
        \tActivation: %s" % (self._dim, self.b, self.w, self._a.__name__)

    def __call__(self, x):
    
        yhat = self._a(np.dot(self.w, np.array(x)) + self.b)
        return yhat
    
class Trainer:

    def __init__(self, dataset, model, loss):
    
        self.dataset = dataset
        self.model = model
        self.loss = loss

    def validate(self, data):

        results = [self.loss(self.model.predict(x), y) for x, y in data]
        return float(sum(result for result in results))/float(len(results))
    
    def accuracy(self, data):
        return 100*float(sum([1 for x, y in data if self.model.predict(x) == y]))/float(len(data))

    def train(self, lr, ne):

        print("training model on data...")
        accuracy = self.accuracy(self.dataset)
        print("initial accuracy: %.3f" % (accuracy))
        for epoch in range(ne):
            for d in self.dataset:
                x, y = d
                x = np.array(x)
                yhat = self.model(x)
                error = y - yhat
                self.model.w += lr*(y-yhat)*x
                self.model.b += lr*(y-yhat)
            accuracy = self.accuracy(self.dataset)
            print('>epoch=%d, learning_rate=%.3f, accuracy=%.3f' % (epoch+1, lr, accuracy))
        print("training complete")
        print("final accuracy: %.3f" % (self.accuracy(self.dataset)))

# activation functions

def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))

def perceptron(z):
    return -1 if z<=0 else 1

# loss functions

def lrloss(yhat, y):
    return -1.0*(y*np.log(yhat)+(1-y)*np.log(1-yhat))

def ploss(yhat, y):
    return max(0, -yhat*y)

# prediction functions

def ppredict(self, x):
    return self(x)

def lrpredict(self, x):
    return 1 if self(x)>0.5 else 0
    
# extra

def softmax(z):
    return np.exp(z) / np.sum(np.exp(z))

# %%
neuron = Neuron(dimension = len(dataset[0][0]), activation = perceptron, predict = ppredict)
trainer = Trainer(dataset, neuron, ploss)
updates = trainer.train(0.01, 8000)
# Out:
# training model on data...
# initial accuracy: 46.635
# >epoch=1, learning_rate=0.010, accuracy=49.038
# >epoch=2, learning_rate=0.010, accuracy=63.942
# >epoch=3, learning_rate=0.010, accuracy=61.538
# >epoch=4, learning_rate=0.010, accuracy=69.712
# >epoch=5, learning_rate=0.010, accuracy=70.673
# >epoch=6, learning_rate=0.010, accuracy=72.115
# >epoch=7, learning_rate=0.010, accuracy=73.558
# >epoch=8, learning_rate=0.010, accuracy=73.558
# >epoch=9, learning_rate=0.010, accuracy=71.635
# >epoch=10, learning_rate=0.010, accuracy=72.115
# >epoch=11, learning_rate=0.010, accuracy=75.481
# >epoch=12, learning_rate=0.010, accuracy=75.481
# >epoch=13, learning_rate=0.010, accuracy=77.404
# >epoch=14, learning_rate=0.010, accuracy=75.962
# >epoch=15, learning_rate=0.010, accuracy=77.404
# >epoch=16, learning_rate=0.010, accuracy=76.923
# >epoch=17, learning_rate=0.010, accuracy=76.923
# >epoch=18, learning_rate=0.010, accuracy=77.404
# >epoch=19, learning_rate=0.010, accuracy=74.519
# >epoch=20, learning_rate=0.010, accuracy=76.442
# >epoch=21, learning_rate=0.010, accuracy=77.885
# >epoch=22, learning_rate=0.010, accuracy=75.481
# >epoch=23, learning_rate=0.010, accuracy=79.327
# >epoch=24, learning_rate=0.010, accuracy=75.000
# >epoch=25, learning_rate=0.010, accuracy=76.923
# >epoch=26, learning_rate=0.010, accuracy=79.327
# >epoch=27, learning_rate=0.010, accuracy=76.923
# >epoch=28, learning_rate=0.010, accuracy=79.808
# >epoch=29, learning_rate=0.010, accuracy=80.288
# >epoch=30, learning_rate=0.010, accuracy=76.923
# >epoch=31, learning_rate=0.010, accuracy=76.442
# >epoch=32, learning_rate=0.010, accuracy=75.962
# >epoch=33, learning_rate=0.010, accuracy=75.481
# >epoch=34, learning_rate=0.010, accuracy=76.923
# >epoch=35, learning_rate=0.010, accuracy=78.365
# >epoch=36, learning_rate=0.010, accuracy=80.288
# >epoch=37, learning_rate=0.010, accuracy=76.923
# >epoch=38, learning_rate=0.010, accuracy=78.365
# >epoch=39, learning_rate=0.010, accuracy=79.808
# >epoch=40, learning_rate=0.010, accuracy=81.731
# >epoch=41, learning_rate=0.010, accuracy=77.404
# >epoch=42, learning_rate=0.010, accuracy=76.442
# >epoch=43, learning_rate=0.010, accuracy=79.327
# >epoch=44, learning_rate=0.010, accuracy=80.769
# >epoch=45, learning_rate=0.010, accuracy=80.769
# >epoch=46, learning_rate=0.010, accuracy=75.962
# >epoch=47, learning_rate=0.010, accuracy=81.250
# >epoch=48, learning_rate=0.010, accuracy=79.808
# >epoch=49, learning_rate=0.010, accuracy=76.923
# >epoch=50, learning_rate=0.010, accuracy=76.442
# >epoch=51, learning_rate=0.010, accuracy=79.808
# >epoch=52, learning_rate=0.010, accuracy=80.769
# >epoch=53, learning_rate=0.010, accuracy=76.442
# >epoch=54, learning_rate=0.010, accuracy=77.404
# >epoch=55, learning_rate=0.010, accuracy=76.923
# >epoch=56, learning_rate=0.010, accuracy=77.885
# >epoch=57, learning_rate=0.010, accuracy=78.365
# >epoch=58, learning_rate=0.010, accuracy=80.769
# >epoch=59, learning_rate=0.010, accuracy=83.654
# >epoch=60, learning_rate=0.010, accuracy=80.769
# >epoch=61, learning_rate=0.010, accuracy=82.212
# >epoch=62, learning_rate=0.010, accuracy=75.962
# >epoch=63, learning_rate=0.010, accuracy=82.212
# >epoch=64, learning_rate=0.010, accuracy=77.404
# >epoch=65, learning_rate=0.010, accuracy=82.212
# >epoch=66, learning_rate=0.010, accuracy=81.731
# >epoch=67, learning_rate=0.010, accuracy=79.808
# >epoch=68, learning_rate=0.010, accuracy=77.885
# >epoch=69, learning_rate=0.010, accuracy=82.692
# >epoch=70, learning_rate=0.010, accuracy=84.135
# >epoch=71, learning_rate=0.010, accuracy=80.769
# >epoch=72, learning_rate=0.010, accuracy=76.923
# >epoch=73, learning_rate=0.010, accuracy=76.442
# >epoch=74, learning_rate=0.010, accuracy=84.135
# >epoch=75, learning_rate=0.010, accuracy=83.654
# >epoch=76, learning_rate=0.010, accuracy=82.212
# >epoch=77, learning_rate=0.010, accuracy=83.173
# >epoch=78, learning_rate=0.010, accuracy=82.692
# >epoch=79, learning_rate=0.010, accuracy=82.692
# >epoch=80, learning_rate=0.010, accuracy=78.846
# >epoch=81, learning_rate=0.010, accuracy=78.365
# >epoch=82, learning_rate=0.010, accuracy=76.923
# >epoch=83, learning_rate=0.010, accuracy=80.769
# >epoch=84, learning_rate=0.010, accuracy=83.173
# >epoch=85, learning_rate=0.010, accuracy=84.135
# >epoch=86, learning_rate=0.010, accuracy=84.135
# >epoch=87, learning_rate=0.010, accuracy=84.135
# >epoch=88, learning_rate=0.010, accuracy=81.250
# >epoch=89, learning_rate=0.010, accuracy=76.442
# >epoch=90, learning_rate=0.010, accuracy=78.846
# >epoch=91, learning_rate=0.010, accuracy=82.692
# >epoch=92, learning_rate=0.010, accuracy=76.923
# >epoch=93, learning_rate=0.010, accuracy=84.615
# >epoch=94, learning_rate=0.010, accuracy=78.365
# >epoch=95, learning_rate=0.010, accuracy=85.096
# >epoch=96, learning_rate=0.010, accuracy=77.885
# >epoch=97, learning_rate=0.010, accuracy=84.135
# >epoch=98, learning_rate=0.010, accuracy=81.731
# >epoch=99, learning_rate=0.010, accuracy=83.654
# >epoch=100, learning_rate=0.010, accuracy=82.692
# >epoch=101, learning_rate=0.010, accuracy=82.692
# >epoch=102, learning_rate=0.010, accuracy=81.250
# >epoch=103, learning_rate=0.010, accuracy=84.615
# >epoch=104, learning_rate=0.010, accuracy=83.654
# >epoch=105, learning_rate=0.010, accuracy=81.731
# >epoch=106, learning_rate=0.010, accuracy=81.250
# >epoch=107, learning_rate=0.010, accuracy=84.615
# >epoch=108, learning_rate=0.010, accuracy=84.135
# >epoch=109, learning_rate=0.010, accuracy=78.846
# >epoch=110, learning_rate=0.010, accuracy=84.615
# >epoch=111, learning_rate=0.010, accuracy=84.135
# >epoch=112, learning_rate=0.010, accuracy=84.135
# >epoch=113, learning_rate=0.010, accuracy=83.654
# >epoch=114, learning_rate=0.010, accuracy=82.692
# >epoch=115, learning_rate=0.010, accuracy=82.692
# >epoch=116, learning_rate=0.010, accuracy=83.173
# >epoch=117, learning_rate=0.010, accuracy=85.096
# >epoch=118, learning_rate=0.010, accuracy=79.808
# >epoch=119, learning_rate=0.010, accuracy=84.135
# >epoch=120, learning_rate=0.010, accuracy=79.808
# >epoch=121, learning_rate=0.010, accuracy=82.692
# >epoch=122, learning_rate=0.010, accuracy=78.365
# >epoch=123, learning_rate=0.010, accuracy=83.173
# >epoch=124, learning_rate=0.010, accuracy=83.654
# >epoch=125, learning_rate=0.010, accuracy=82.692
# >epoch=126, learning_rate=0.010, accuracy=75.481
# >epoch=127, learning_rate=0.010, accuracy=82.212
# >epoch=128, learning_rate=0.010, accuracy=84.135
# >epoch=129, learning_rate=0.010, accuracy=83.654
# >epoch=130, learning_rate=0.010, accuracy=84.135
# >epoch=131, learning_rate=0.010, accuracy=82.692
# >epoch=132, learning_rate=0.010, accuracy=83.654
# >epoch=133, learning_rate=0.010, accuracy=80.288
# >epoch=134, learning_rate=0.010, accuracy=83.654
# >epoch=135, learning_rate=0.010, accuracy=78.365
# >epoch=136, learning_rate=0.010, accuracy=84.615
# >epoch=137, learning_rate=0.010, accuracy=78.365
# >epoch=138, learning_rate=0.010, accuracy=83.173
# >epoch=139, learning_rate=0.010, accuracy=84.615
# >epoch=140, learning_rate=0.010, accuracy=79.327
# >epoch=141, learning_rate=0.010, accuracy=83.173
# >epoch=142, learning_rate=0.010, accuracy=84.615
# >epoch=143, learning_rate=0.010, accuracy=84.135
# >epoch=144, learning_rate=0.010, accuracy=83.654
# >epoch=145, learning_rate=0.010, accuracy=79.808
# >epoch=146, learning_rate=0.010, accuracy=82.212
# >epoch=147, learning_rate=0.010, accuracy=81.731
# >epoch=148, learning_rate=0.010, accuracy=83.654
# >epoch=149, learning_rate=0.010, accuracy=81.250
# >epoch=150, learning_rate=0.010, accuracy=84.615
# >epoch=151, learning_rate=0.010, accuracy=83.654
# >epoch=152, learning_rate=0.010, accuracy=84.135
# >epoch=153, learning_rate=0.010, accuracy=80.769
# >epoch=154, learning_rate=0.010, accuracy=77.404
# >epoch=155, learning_rate=0.010, accuracy=84.135
# >epoch=156, learning_rate=0.010, accuracy=82.212
# >epoch=157, learning_rate=0.010, accuracy=85.096
# >epoch=158, learning_rate=0.010, accuracy=81.731
# >epoch=159, learning_rate=0.010, accuracy=84.615
# >epoch=160, learning_rate=0.010, accuracy=83.173
# >epoch=161, learning_rate=0.010, accuracy=82.212
# >epoch=162, learning_rate=0.010, accuracy=85.096
# >epoch=163, learning_rate=0.010, accuracy=83.654
# >epoch=164, learning_rate=0.010, accuracy=83.654
# >epoch=165, learning_rate=0.010, accuracy=82.212
# >epoch=166, learning_rate=0.010, accuracy=78.365
# >epoch=167, learning_rate=0.010, accuracy=82.212
# >epoch=168, learning_rate=0.010, accuracy=80.288
# >epoch=169, learning_rate=0.010, accuracy=85.096
# >epoch=170, learning_rate=0.010, accuracy=84.135
# >epoch=171, learning_rate=0.010, accuracy=82.692
# >epoch=172, learning_rate=0.010, accuracy=81.250
# >epoch=173, learning_rate=0.010, accuracy=83.173
# >epoch=174, learning_rate=0.010, accuracy=79.327
# >epoch=175, learning_rate=0.010, accuracy=83.654
# >epoch=176, learning_rate=0.010, accuracy=83.173
# >epoch=177, learning_rate=0.010, accuracy=84.135
# >epoch=178, learning_rate=0.010, accuracy=77.885
# >epoch=179, learning_rate=0.010, accuracy=82.692
# >epoch=180, learning_rate=0.010, accuracy=84.615
# >epoch=181, learning_rate=0.010, accuracy=82.212
# >epoch=182, learning_rate=0.010, accuracy=81.250
# >epoch=183, learning_rate=0.010, accuracy=84.135
# >epoch=184, learning_rate=0.010, accuracy=81.731
# >epoch=185, learning_rate=0.010, accuracy=75.962
# >epoch=186, learning_rate=0.010, accuracy=82.692
# >epoch=187, learning_rate=0.010, accuracy=78.365
# >epoch=188, learning_rate=0.010, accuracy=80.769
# >epoch=189, learning_rate=0.010, accuracy=83.173
# >epoch=190, learning_rate=0.010, accuracy=81.731
# >epoch=191, learning_rate=0.010, accuracy=83.173
# >epoch=192, learning_rate=0.010, accuracy=82.692
# >epoch=193, learning_rate=0.010, accuracy=83.173
# >epoch=194, learning_rate=0.010, accuracy=82.692
# >epoch=195, learning_rate=0.010, accuracy=83.173
# >epoch=196, learning_rate=0.010, accuracy=83.654
# >epoch=197, learning_rate=0.010, accuracy=80.288
# >epoch=198, learning_rate=0.010, accuracy=83.654
# >epoch=199, learning_rate=0.010, accuracy=83.654
# >epoch=200, learning_rate=0.010, accuracy=83.654
# >epoch=201, learning_rate=0.010, accuracy=83.173
# >epoch=202, learning_rate=0.010, accuracy=80.769
# >epoch=203, learning_rate=0.010, accuracy=83.173
# >epoch=204, learning_rate=0.010, accuracy=84.135
# >epoch=205, learning_rate=0.010, accuracy=84.135
# >epoch=206, learning_rate=0.010, accuracy=85.096
# >epoch=207, learning_rate=0.010, accuracy=84.135
# >epoch=208, learning_rate=0.010, accuracy=83.173
# >epoch=209, learning_rate=0.010, accuracy=76.923
# >epoch=210, learning_rate=0.010, accuracy=82.692
# >epoch=211, learning_rate=0.010, accuracy=83.173
# >epoch=212, learning_rate=0.010, accuracy=84.615
# >epoch=213, learning_rate=0.010, accuracy=82.692
# >epoch=214, learning_rate=0.010, accuracy=81.731
# >epoch=215, learning_rate=0.010, accuracy=75.000
# >epoch=216, learning_rate=0.010, accuracy=84.135
# >epoch=217, learning_rate=0.010, accuracy=84.135
# >epoch=218, learning_rate=0.010, accuracy=83.654
# >epoch=219, learning_rate=0.010, accuracy=84.615
# >epoch=220, learning_rate=0.010, accuracy=82.692
# >epoch=221, learning_rate=0.010, accuracy=83.173
# >epoch=222, learning_rate=0.010, accuracy=83.654
# >epoch=223, learning_rate=0.010, accuracy=84.615
# >epoch=224, learning_rate=0.010, accuracy=83.173
# >epoch=225, learning_rate=0.010, accuracy=82.692
# >epoch=226, learning_rate=0.010, accuracy=83.173
# >epoch=227, learning_rate=0.010, accuracy=84.135
# >epoch=228, learning_rate=0.010, accuracy=84.615
# >epoch=229, learning_rate=0.010, accuracy=83.173
# >epoch=230, learning_rate=0.010, accuracy=84.615
# >epoch=231, learning_rate=0.010, accuracy=84.135
# >epoch=232, learning_rate=0.010, accuracy=80.288
# >epoch=233, learning_rate=0.010, accuracy=83.654
# >epoch=234, learning_rate=0.010, accuracy=83.654
# >epoch=235, learning_rate=0.010, accuracy=83.173
# >epoch=236, learning_rate=0.010, accuracy=84.615
# >epoch=237, learning_rate=0.010, accuracy=83.173
# >epoch=238, learning_rate=0.010, accuracy=84.135
# >epoch=239, learning_rate=0.010, accuracy=83.654
# >epoch=240, learning_rate=0.010, accuracy=84.135
# >epoch=241, learning_rate=0.010, accuracy=84.135
# >epoch=242, learning_rate=0.010, accuracy=82.692
# >epoch=243, learning_rate=0.010, accuracy=83.173
# >epoch=244, learning_rate=0.010, accuracy=85.577
# >epoch=245, learning_rate=0.010, accuracy=85.577
# >epoch=246, learning_rate=0.010, accuracy=86.538
# >epoch=247, learning_rate=0.010, accuracy=81.731
# >epoch=248, learning_rate=0.010, accuracy=81.250
# >epoch=249, learning_rate=0.010, accuracy=87.019
# >epoch=250, learning_rate=0.010, accuracy=83.654
# >epoch=251, learning_rate=0.010, accuracy=86.538
# >epoch=252, learning_rate=0.010, accuracy=81.250
# >epoch=253, learning_rate=0.010, accuracy=83.173
# >epoch=254, learning_rate=0.010, accuracy=87.019
# >epoch=255, learning_rate=0.010, accuracy=84.615
# >epoch=256, learning_rate=0.010, accuracy=83.654
# >epoch=257, learning_rate=0.010, accuracy=85.096
# >epoch=258, learning_rate=0.010, accuracy=81.250
# >epoch=259, learning_rate=0.010, accuracy=84.135
# >epoch=260, learning_rate=0.010, accuracy=81.731
# >epoch=261, learning_rate=0.010, accuracy=83.173
# >epoch=262, learning_rate=0.010, accuracy=80.288
# >epoch=263, learning_rate=0.010, accuracy=81.250
# >epoch=264, learning_rate=0.010, accuracy=81.731
# >epoch=265, learning_rate=0.010, accuracy=83.173
# >epoch=266, learning_rate=0.010, accuracy=82.692
# >epoch=267, learning_rate=0.010, accuracy=81.250
# >epoch=268, learning_rate=0.010, accuracy=82.692
# >epoch=269, learning_rate=0.010, accuracy=83.654
# >epoch=270, learning_rate=0.010, accuracy=86.058
# >epoch=271, learning_rate=0.010, accuracy=87.500
# >epoch=272, learning_rate=0.010, accuracy=83.173
# >epoch=273, learning_rate=0.010, accuracy=83.654
# >epoch=274, learning_rate=0.010, accuracy=80.288
# >epoch=275, learning_rate=0.010, accuracy=86.538
# >epoch=276, learning_rate=0.010, accuracy=86.538
# >epoch=277, learning_rate=0.010, accuracy=85.096
# >epoch=278, learning_rate=0.010, accuracy=85.096
# >epoch=279, learning_rate=0.010, accuracy=83.173
# >epoch=280, learning_rate=0.010, accuracy=81.250
# >epoch=281, learning_rate=0.010, accuracy=84.615
# >epoch=282, learning_rate=0.010, accuracy=80.769
# >epoch=283, learning_rate=0.010, accuracy=80.769
# >epoch=284, learning_rate=0.010, accuracy=84.135
# >epoch=285, learning_rate=0.010, accuracy=84.615
# >epoch=286, learning_rate=0.010, accuracy=81.250
# >epoch=287, learning_rate=0.010, accuracy=82.212
# >epoch=288, learning_rate=0.010, accuracy=82.212
# >epoch=289, learning_rate=0.010, accuracy=84.135
# >epoch=290, learning_rate=0.010, accuracy=81.250
# >epoch=291, learning_rate=0.010, accuracy=87.019
# >epoch=292, learning_rate=0.010, accuracy=81.250
# >epoch=293, learning_rate=0.010, accuracy=81.250
# >epoch=294, learning_rate=0.010, accuracy=82.212
# >epoch=295, learning_rate=0.010, accuracy=81.731
# >epoch=296, learning_rate=0.010, accuracy=82.212
# >epoch=297, learning_rate=0.010, accuracy=81.250
# >epoch=298, learning_rate=0.010, accuracy=83.654
# >epoch=299, learning_rate=0.010, accuracy=86.058
# >epoch=300, learning_rate=0.010, accuracy=86.538
# >epoch=301, learning_rate=0.010, accuracy=81.731
# >epoch=302, learning_rate=0.010, accuracy=80.769
# >epoch=303, learning_rate=0.010, accuracy=82.212
# >epoch=304, learning_rate=0.010, accuracy=85.096
# >epoch=305, learning_rate=0.010, accuracy=81.250
# >epoch=306, learning_rate=0.010, accuracy=84.135
# >epoch=307, learning_rate=0.010, accuracy=81.250
# >epoch=308, learning_rate=0.010, accuracy=79.808
# >epoch=309, learning_rate=0.010, accuracy=81.731
# >epoch=310, learning_rate=0.010, accuracy=87.019
# >epoch=311, learning_rate=0.010, accuracy=84.135
# >epoch=312, learning_rate=0.010, accuracy=81.250
# >epoch=313, learning_rate=0.010, accuracy=85.096
# >epoch=314, learning_rate=0.010, accuracy=82.692
# >epoch=315, learning_rate=0.010, accuracy=81.731
# >epoch=316, learning_rate=0.010, accuracy=84.135
# >epoch=317, learning_rate=0.010, accuracy=85.096
# >epoch=318, learning_rate=0.010, accuracy=86.058
# >epoch=319, learning_rate=0.010, accuracy=81.731
# >epoch=320, learning_rate=0.010, accuracy=83.654
# >epoch=321, learning_rate=0.010, accuracy=83.173
# >epoch=322, learning_rate=0.010, accuracy=83.654
# >epoch=323, learning_rate=0.010, accuracy=81.250
# >epoch=324, learning_rate=0.010, accuracy=81.250
# >epoch=325, learning_rate=0.010, accuracy=81.731
# >epoch=326, learning_rate=0.010, accuracy=81.731
# >epoch=327, learning_rate=0.010, accuracy=81.250
# >epoch=328, learning_rate=0.010, accuracy=84.135
# >epoch=329, learning_rate=0.010, accuracy=82.212
# >epoch=330, learning_rate=0.010, accuracy=80.769
# >epoch=331, learning_rate=0.010, accuracy=81.250
# >epoch=332, learning_rate=0.010, accuracy=80.769
# >epoch=333, learning_rate=0.010, accuracy=81.731
# >epoch=334, learning_rate=0.010, accuracy=85.096
# >epoch=335, learning_rate=0.010, accuracy=81.250
# >epoch=336, learning_rate=0.010, accuracy=80.769
# >epoch=337, learning_rate=0.010, accuracy=84.135
# >epoch=338, learning_rate=0.010, accuracy=82.692
# >epoch=339, learning_rate=0.010, accuracy=82.212
# >epoch=340, learning_rate=0.010, accuracy=81.250
# >epoch=341, learning_rate=0.010, accuracy=81.250
# >epoch=342, learning_rate=0.010, accuracy=86.538
# >epoch=343, learning_rate=0.010, accuracy=86.058
# >epoch=344, learning_rate=0.010, accuracy=84.615
# >epoch=345, learning_rate=0.010, accuracy=84.615
# >epoch=346, learning_rate=0.010, accuracy=86.058
# >epoch=347, learning_rate=0.010, accuracy=81.731
# >epoch=348, learning_rate=0.010, accuracy=81.731
# >epoch=349, learning_rate=0.010, accuracy=84.135
# >epoch=350, learning_rate=0.010, accuracy=85.577
# >epoch=351, learning_rate=0.010, accuracy=83.173
# >epoch=352, learning_rate=0.010, accuracy=83.654
# >epoch=353, learning_rate=0.010, accuracy=81.731
# >epoch=354, learning_rate=0.010, accuracy=81.250
# >epoch=355, learning_rate=0.010, accuracy=81.731
# >epoch=356, learning_rate=0.010, accuracy=81.731
# >epoch=357, learning_rate=0.010, accuracy=83.654
# >epoch=358, learning_rate=0.010, accuracy=81.731
# >epoch=359, learning_rate=0.010, accuracy=85.096
# >epoch=360, learning_rate=0.010, accuracy=84.135
# >epoch=361, learning_rate=0.010, accuracy=81.250
# >epoch=362, learning_rate=0.010, accuracy=86.058
# >epoch=363, learning_rate=0.010, accuracy=82.692
# >epoch=364, learning_rate=0.010, accuracy=81.731
# >epoch=365, learning_rate=0.010, accuracy=82.692
# >epoch=366, learning_rate=0.010, accuracy=81.250
# >epoch=367, learning_rate=0.010, accuracy=81.250
# >epoch=368, learning_rate=0.010, accuracy=84.615
# >epoch=369, learning_rate=0.010, accuracy=84.135
# >epoch=370, learning_rate=0.010, accuracy=86.058
# >epoch=371, learning_rate=0.010, accuracy=84.615
# >epoch=372, learning_rate=0.010, accuracy=85.577
# >epoch=373, learning_rate=0.010, accuracy=81.731
# >epoch=374, learning_rate=0.010, accuracy=81.250
# >epoch=375, learning_rate=0.010, accuracy=81.731
# >epoch=376, learning_rate=0.010, accuracy=82.692
# >epoch=377, learning_rate=0.010, accuracy=83.173
# >epoch=378, learning_rate=0.010, accuracy=83.654
# >epoch=379, learning_rate=0.010, accuracy=83.173
# >epoch=380, learning_rate=0.010, accuracy=84.135
# >epoch=381, learning_rate=0.010, accuracy=82.692
# >epoch=382, learning_rate=0.010, accuracy=81.250
# >epoch=383, learning_rate=0.010, accuracy=83.654
# >epoch=384, learning_rate=0.010, accuracy=81.731
# >epoch=385, learning_rate=0.010, accuracy=81.731
# >epoch=386, learning_rate=0.010, accuracy=83.173
# >epoch=387, learning_rate=0.010, accuracy=81.250
# >epoch=388, learning_rate=0.010, accuracy=84.135
# >epoch=389, learning_rate=0.010, accuracy=86.538
# >epoch=390, learning_rate=0.010, accuracy=82.692
# >epoch=391, learning_rate=0.010, accuracy=81.731
# >epoch=392, learning_rate=0.010, accuracy=81.731
# >epoch=393, learning_rate=0.010, accuracy=82.692
# >epoch=394, learning_rate=0.010, accuracy=83.654
# >epoch=395, learning_rate=0.010, accuracy=83.654
# >epoch=396, learning_rate=0.010, accuracy=82.212
# >epoch=397, learning_rate=0.010, accuracy=85.577
# >epoch=398, learning_rate=0.010, accuracy=80.769
# >epoch=399, learning_rate=0.010, accuracy=81.731
# >epoch=400, learning_rate=0.010, accuracy=85.096
# >epoch=401, learning_rate=0.010, accuracy=84.135
# >epoch=402, learning_rate=0.010, accuracy=82.212
# >epoch=403, learning_rate=0.010, accuracy=82.212
# >epoch=404, learning_rate=0.010, accuracy=81.250
# >epoch=405, learning_rate=0.010, accuracy=86.058
# >epoch=406, learning_rate=0.010, accuracy=83.654
# >epoch=407, learning_rate=0.010, accuracy=83.173
# >epoch=408, learning_rate=0.010, accuracy=82.692
# >epoch=409, learning_rate=0.010, accuracy=82.692
# >epoch=410, learning_rate=0.010, accuracy=83.654
# >epoch=411, learning_rate=0.010, accuracy=84.135
# >epoch=412, learning_rate=0.010, accuracy=83.654
# >epoch=413, learning_rate=0.010, accuracy=84.615
# >epoch=414, learning_rate=0.010, accuracy=84.135
# >epoch=415, learning_rate=0.010, accuracy=83.173
# >epoch=416, learning_rate=0.010, accuracy=83.173
# >epoch=417, learning_rate=0.010, accuracy=82.692
# >epoch=418, learning_rate=0.010, accuracy=85.096
# >epoch=419, learning_rate=0.010, accuracy=83.654
# >epoch=420, learning_rate=0.010, accuracy=81.731
# >epoch=421, learning_rate=0.010, accuracy=81.731
# >epoch=422, learning_rate=0.010, accuracy=83.173
# >epoch=423, learning_rate=0.010, accuracy=83.654
# >epoch=424, learning_rate=0.010, accuracy=85.096
# >epoch=425, learning_rate=0.010, accuracy=84.615
# >epoch=426, learning_rate=0.010, accuracy=82.212
# >epoch=427, learning_rate=0.010, accuracy=85.096
# >epoch=428, learning_rate=0.010, accuracy=84.135
# >epoch=429, learning_rate=0.010, accuracy=77.404
# >epoch=430, learning_rate=0.010, accuracy=78.365
# >epoch=431, learning_rate=0.010, accuracy=85.096
# >epoch=432, learning_rate=0.010, accuracy=81.731
# >epoch=433, learning_rate=0.010, accuracy=83.654
# >epoch=434, learning_rate=0.010, accuracy=84.615
# >epoch=435, learning_rate=0.010, accuracy=81.250
# >epoch=436, learning_rate=0.010, accuracy=86.058
# >epoch=437, learning_rate=0.010, accuracy=84.135
# >epoch=438, learning_rate=0.010, accuracy=85.096
# >epoch=439, learning_rate=0.010, accuracy=83.173
# >epoch=440, learning_rate=0.010, accuracy=84.615
# >epoch=441, learning_rate=0.010, accuracy=86.058
# >epoch=442, learning_rate=0.010, accuracy=83.173
# >epoch=443, learning_rate=0.010, accuracy=85.096
# >epoch=444, learning_rate=0.010, accuracy=82.212
# >epoch=445, learning_rate=0.010, accuracy=82.692
# >epoch=446, learning_rate=0.010, accuracy=85.096
# >epoch=447, learning_rate=0.010, accuracy=81.731
# >epoch=448, learning_rate=0.010, accuracy=81.731
# >epoch=449, learning_rate=0.010, accuracy=84.615
# >epoch=450, learning_rate=0.010, accuracy=82.212
# >epoch=451, learning_rate=0.010, accuracy=85.577
# >epoch=452, learning_rate=0.010, accuracy=86.538
# >epoch=453, learning_rate=0.010, accuracy=84.615
# >epoch=454, learning_rate=0.010, accuracy=85.096
# >epoch=455, learning_rate=0.010, accuracy=84.135
# >epoch=456, learning_rate=0.010, accuracy=86.538
# >epoch=457, learning_rate=0.010, accuracy=83.654
# >epoch=458, learning_rate=0.010, accuracy=81.731
# >epoch=459, learning_rate=0.010, accuracy=84.615
# >epoch=460, learning_rate=0.010, accuracy=80.769
# >epoch=461, learning_rate=0.010, accuracy=82.212
# >epoch=462, learning_rate=0.010, accuracy=82.212
# >epoch=463, learning_rate=0.010, accuracy=84.615
# >epoch=464, learning_rate=0.010, accuracy=83.654
# >epoch=465, learning_rate=0.010, accuracy=82.212
# >epoch=466, learning_rate=0.010, accuracy=84.135
# >epoch=467, learning_rate=0.010, accuracy=80.288
# >epoch=468, learning_rate=0.010, accuracy=84.615
# >epoch=469, learning_rate=0.010, accuracy=84.615
# >epoch=470, learning_rate=0.010, accuracy=81.250
# >epoch=471, learning_rate=0.010, accuracy=84.135
# >epoch=472, learning_rate=0.010, accuracy=85.096
# >epoch=473, learning_rate=0.010, accuracy=81.250
# >epoch=474, learning_rate=0.010, accuracy=85.577
# >epoch=475, learning_rate=0.010, accuracy=81.731
# >epoch=476, learning_rate=0.010, accuracy=83.654
# >epoch=477, learning_rate=0.010, accuracy=85.096
# >epoch=478, learning_rate=0.010, accuracy=83.173
# >epoch=479, learning_rate=0.010, accuracy=82.212
# >epoch=480, learning_rate=0.010, accuracy=83.654
# >epoch=481, learning_rate=0.010, accuracy=83.654
# >epoch=482, learning_rate=0.010, accuracy=84.135
# >epoch=483, learning_rate=0.010, accuracy=84.135
# >epoch=484, learning_rate=0.010, accuracy=85.577
# >epoch=485, learning_rate=0.010, accuracy=83.173
# >epoch=486, learning_rate=0.010, accuracy=83.173
# >epoch=487, learning_rate=0.010, accuracy=81.731
# >epoch=488, learning_rate=0.010, accuracy=84.615
# >epoch=489, learning_rate=0.010, accuracy=80.288
# >epoch=490, learning_rate=0.010, accuracy=85.577
# >epoch=491, learning_rate=0.010, accuracy=87.019
# >epoch=492, learning_rate=0.010, accuracy=84.135
# >epoch=493, learning_rate=0.010, accuracy=82.692
# >epoch=494, learning_rate=0.010, accuracy=84.135
# >epoch=495, learning_rate=0.010, accuracy=85.096
# >epoch=496, learning_rate=0.010, accuracy=83.654
# >epoch=497, learning_rate=0.010, accuracy=84.135
# >epoch=498, learning_rate=0.010, accuracy=84.135
# >epoch=499, learning_rate=0.010, accuracy=81.731
# >epoch=500, learning_rate=0.010, accuracy=86.058
# >epoch=501, learning_rate=0.010, accuracy=81.250
# >epoch=502, learning_rate=0.010, accuracy=82.212
# >epoch=503, learning_rate=0.010, accuracy=84.615
# >epoch=504, learning_rate=0.010, accuracy=85.577
# >epoch=505, learning_rate=0.010, accuracy=85.577
# >epoch=506, learning_rate=0.010, accuracy=86.058
# >epoch=507, learning_rate=0.010, accuracy=84.615
# >epoch=508, learning_rate=0.010, accuracy=87.019
# >epoch=509, learning_rate=0.010, accuracy=84.615
# >epoch=510, learning_rate=0.010, accuracy=75.962
# >epoch=511, learning_rate=0.010, accuracy=85.577
# >epoch=512, learning_rate=0.010, accuracy=85.096
# >epoch=513, learning_rate=0.010, accuracy=84.615
# >epoch=514, learning_rate=0.010, accuracy=86.058
# >epoch=515, learning_rate=0.010, accuracy=82.212
# >epoch=516, learning_rate=0.010, accuracy=87.500
# >epoch=517, learning_rate=0.010, accuracy=79.808
# >epoch=518, learning_rate=0.010, accuracy=85.577
# >epoch=519, learning_rate=0.010, accuracy=81.250
# >epoch=520, learning_rate=0.010, accuracy=78.846
# >epoch=521, learning_rate=0.010, accuracy=84.135
# >epoch=522, learning_rate=0.010, accuracy=81.250
# >epoch=523, learning_rate=0.010, accuracy=83.654
# >epoch=524, learning_rate=0.010, accuracy=86.538
# >epoch=525, learning_rate=0.010, accuracy=85.096
# >epoch=526, learning_rate=0.010, accuracy=83.173
# >epoch=527, learning_rate=0.010, accuracy=83.173
# >epoch=528, learning_rate=0.010, accuracy=82.692
# >epoch=529, learning_rate=0.010, accuracy=82.212
# >epoch=530, learning_rate=0.010, accuracy=83.173
# >epoch=531, learning_rate=0.010, accuracy=81.731
# >epoch=532, learning_rate=0.010, accuracy=84.135
# >epoch=533, learning_rate=0.010, accuracy=83.173
# >epoch=534, learning_rate=0.010, accuracy=82.212
# >epoch=535, learning_rate=0.010, accuracy=80.769
# >epoch=536, learning_rate=0.010, accuracy=83.173
# >epoch=537, learning_rate=0.010, accuracy=87.981
# >epoch=538, learning_rate=0.010, accuracy=81.731
# >epoch=539, learning_rate=0.010, accuracy=75.962
# >epoch=540, learning_rate=0.010, accuracy=84.615
# >epoch=541, learning_rate=0.010, accuracy=82.212
# >epoch=542, learning_rate=0.010, accuracy=84.135
# >epoch=543, learning_rate=0.010, accuracy=82.692
# >epoch=544, learning_rate=0.010, accuracy=85.096
# >epoch=545, learning_rate=0.010, accuracy=84.615
# >epoch=546, learning_rate=0.010, accuracy=82.212
# >epoch=547, learning_rate=0.010, accuracy=83.654
# >epoch=548, learning_rate=0.010, accuracy=87.019
# >epoch=549, learning_rate=0.010, accuracy=81.250
# >epoch=550, learning_rate=0.010, accuracy=86.538
# >epoch=551, learning_rate=0.010, accuracy=81.731
# >epoch=552, learning_rate=0.010, accuracy=84.615
# >epoch=553, learning_rate=0.010, accuracy=77.404
# >epoch=554, learning_rate=0.010, accuracy=84.135
# >epoch=555, learning_rate=0.010, accuracy=81.731
# >epoch=556, learning_rate=0.010, accuracy=81.250
# >epoch=557, learning_rate=0.010, accuracy=86.058
# >epoch=558, learning_rate=0.010, accuracy=85.096
# >epoch=559, learning_rate=0.010, accuracy=87.019
# >epoch=560, learning_rate=0.010, accuracy=85.096
# >epoch=561, learning_rate=0.010, accuracy=82.212
# >epoch=562, learning_rate=0.010, accuracy=85.096
# >epoch=563, learning_rate=0.010, accuracy=83.654
# >epoch=564, learning_rate=0.010, accuracy=83.654
# >epoch=565, learning_rate=0.010, accuracy=85.096
# >epoch=566, learning_rate=0.010, accuracy=84.615
# >epoch=567, learning_rate=0.010, accuracy=81.250
# >epoch=568, learning_rate=0.010, accuracy=85.577
# >epoch=569, learning_rate=0.010, accuracy=86.058
# >epoch=570, learning_rate=0.010, accuracy=83.654
# >epoch=571, learning_rate=0.010, accuracy=83.654
# >epoch=572, learning_rate=0.010, accuracy=83.654
# >epoch=573, learning_rate=0.010, accuracy=85.577
# >epoch=574, learning_rate=0.010, accuracy=79.327
# >epoch=575, learning_rate=0.010, accuracy=82.212
# >epoch=576, learning_rate=0.010, accuracy=84.615
# >epoch=577, learning_rate=0.010, accuracy=84.615
# >epoch=578, learning_rate=0.010, accuracy=79.808
# >epoch=579, learning_rate=0.010, accuracy=84.135
# >epoch=580, learning_rate=0.010, accuracy=81.731
# >epoch=581, learning_rate=0.010, accuracy=82.212
# >epoch=582, learning_rate=0.010, accuracy=82.212
# >epoch=583, learning_rate=0.010, accuracy=86.538
# >epoch=584, learning_rate=0.010, accuracy=84.615
# >epoch=585, learning_rate=0.010, accuracy=85.577
# >epoch=586, learning_rate=0.010, accuracy=83.173
# >epoch=587, learning_rate=0.010, accuracy=83.654
# >epoch=588, learning_rate=0.010, accuracy=85.096
# >epoch=589, learning_rate=0.010, accuracy=83.173
# >epoch=590, learning_rate=0.010, accuracy=86.058
# >epoch=591, learning_rate=0.010, accuracy=83.173
# >epoch=592, learning_rate=0.010, accuracy=85.577
# >epoch=593, learning_rate=0.010, accuracy=87.500
# >epoch=594, learning_rate=0.010, accuracy=83.173
# >epoch=595, learning_rate=0.010, accuracy=86.058
# >epoch=596, learning_rate=0.010, accuracy=85.577
# >epoch=597, learning_rate=0.010, accuracy=85.577
# >epoch=598, learning_rate=0.010, accuracy=83.173
# >epoch=599, learning_rate=0.010, accuracy=85.577
# >epoch=600, learning_rate=0.010, accuracy=84.615
# >epoch=601, learning_rate=0.010, accuracy=82.212
# >epoch=602, learning_rate=0.010, accuracy=84.135
# >epoch=603, learning_rate=0.010, accuracy=80.288
# >epoch=604, learning_rate=0.010, accuracy=84.615
# >epoch=605, learning_rate=0.010, accuracy=82.692
# >epoch=606, learning_rate=0.010, accuracy=82.692
# >epoch=607, learning_rate=0.010, accuracy=80.769
# >epoch=608, learning_rate=0.010, accuracy=82.212
# >epoch=609, learning_rate=0.010, accuracy=86.538
# >epoch=610, learning_rate=0.010, accuracy=85.577
# >epoch=611, learning_rate=0.010, accuracy=82.692
# >epoch=612, learning_rate=0.010, accuracy=84.135
# >epoch=613, learning_rate=0.010, accuracy=84.615
# >epoch=614, learning_rate=0.010, accuracy=84.135
# >epoch=615, learning_rate=0.010, accuracy=81.250
# >epoch=616, learning_rate=0.010, accuracy=86.538
# >epoch=617, learning_rate=0.010, accuracy=86.538
# >epoch=618, learning_rate=0.010, accuracy=86.058
# >epoch=619, learning_rate=0.010, accuracy=81.250
# >epoch=620, learning_rate=0.010, accuracy=86.058
# >epoch=621, learning_rate=0.010, accuracy=81.731
# >epoch=622, learning_rate=0.010, accuracy=86.538
# >epoch=623, learning_rate=0.010, accuracy=81.250
# >epoch=624, learning_rate=0.010, accuracy=86.538
# >epoch=625, learning_rate=0.010, accuracy=86.538
# >epoch=626, learning_rate=0.010, accuracy=86.538
# >epoch=627, learning_rate=0.010, accuracy=83.173
# >epoch=628, learning_rate=0.010, accuracy=84.615
# >epoch=629, learning_rate=0.010, accuracy=83.654
# >epoch=630, learning_rate=0.010, accuracy=83.654
# >epoch=631, learning_rate=0.010, accuracy=83.173
# >epoch=632, learning_rate=0.010, accuracy=85.577
# >epoch=633, learning_rate=0.010, accuracy=83.173
# >epoch=634, learning_rate=0.010, accuracy=85.096
# >epoch=635, learning_rate=0.010, accuracy=83.654
# >epoch=636, learning_rate=0.010, accuracy=85.096
# >epoch=637, learning_rate=0.010, accuracy=85.577
# >epoch=638, learning_rate=0.010, accuracy=82.212
# >epoch=639, learning_rate=0.010, accuracy=82.212
# >epoch=640, learning_rate=0.010, accuracy=84.135
# >epoch=641, learning_rate=0.010, accuracy=83.173
# >epoch=642, learning_rate=0.010, accuracy=84.615
# >epoch=643, learning_rate=0.010, accuracy=86.538
# >epoch=644, learning_rate=0.010, accuracy=87.500
# >epoch=645, learning_rate=0.010, accuracy=82.692
# >epoch=646, learning_rate=0.010, accuracy=83.654
# >epoch=647, learning_rate=0.010, accuracy=82.212
# >epoch=648, learning_rate=0.010, accuracy=82.692
# >epoch=649, learning_rate=0.010, accuracy=84.615
# >epoch=650, learning_rate=0.010, accuracy=85.096
# >epoch=651, learning_rate=0.010, accuracy=84.135
# >epoch=652, learning_rate=0.010, accuracy=87.019
# >epoch=653, learning_rate=0.010, accuracy=84.615
# >epoch=654, learning_rate=0.010, accuracy=87.500
# >epoch=655, learning_rate=0.010, accuracy=83.654
# >epoch=656, learning_rate=0.010, accuracy=80.288
# >epoch=657, learning_rate=0.010, accuracy=85.096
# >epoch=658, learning_rate=0.010, accuracy=82.692
# >epoch=659, learning_rate=0.010, accuracy=85.577
# >epoch=660, learning_rate=0.010, accuracy=85.577
# >epoch=661, learning_rate=0.010, accuracy=81.250
# >epoch=662, learning_rate=0.010, accuracy=85.096
# >epoch=663, learning_rate=0.010, accuracy=84.615
# >epoch=664, learning_rate=0.010, accuracy=85.577
# >epoch=665, learning_rate=0.010, accuracy=85.096
# >epoch=666, learning_rate=0.010, accuracy=82.212
# >epoch=667, learning_rate=0.010, accuracy=85.577
# >epoch=668, learning_rate=0.010, accuracy=85.096
# >epoch=669, learning_rate=0.010, accuracy=78.846
# >epoch=670, learning_rate=0.010, accuracy=80.769
# >epoch=671, learning_rate=0.010, accuracy=87.019
# >epoch=672, learning_rate=0.010, accuracy=85.096
# >epoch=673, learning_rate=0.010, accuracy=83.173
# >epoch=674, learning_rate=0.010, accuracy=85.096
# >epoch=675, learning_rate=0.010, accuracy=85.096
# >epoch=676, learning_rate=0.010, accuracy=85.577
# >epoch=677, learning_rate=0.010, accuracy=87.019
# >epoch=678, learning_rate=0.010, accuracy=84.615
# >epoch=679, learning_rate=0.010, accuracy=86.058
# >epoch=680, learning_rate=0.010, accuracy=82.212
# >epoch=681, learning_rate=0.010, accuracy=83.654
# >epoch=682, learning_rate=0.010, accuracy=84.135
# >epoch=683, learning_rate=0.010, accuracy=86.538
# >epoch=684, learning_rate=0.010, accuracy=84.615
# >epoch=685, learning_rate=0.010, accuracy=84.615
# >epoch=686, learning_rate=0.010, accuracy=84.615
# >epoch=687, learning_rate=0.010, accuracy=83.654
# >epoch=688, learning_rate=0.010, accuracy=81.731
# >epoch=689, learning_rate=0.010, accuracy=81.731
# >epoch=690, learning_rate=0.010, accuracy=86.538
# >epoch=691, learning_rate=0.010, accuracy=82.692
# >epoch=692, learning_rate=0.010, accuracy=86.538
# >epoch=693, learning_rate=0.010, accuracy=86.538
# >epoch=694, learning_rate=0.010, accuracy=87.019
# >epoch=695, learning_rate=0.010, accuracy=84.615
# >epoch=696, learning_rate=0.010, accuracy=84.615
# >epoch=697, learning_rate=0.010, accuracy=86.538
# >epoch=698, learning_rate=0.010, accuracy=85.096
# >epoch=699, learning_rate=0.010, accuracy=87.019
# >epoch=700, learning_rate=0.010, accuracy=86.538
# >epoch=701, learning_rate=0.010, accuracy=83.654
# >epoch=702, learning_rate=0.010, accuracy=84.135
# >epoch=703, learning_rate=0.010, accuracy=87.019
# >epoch=704, learning_rate=0.010, accuracy=82.692
# >epoch=705, learning_rate=0.010, accuracy=87.019
# >epoch=706, learning_rate=0.010, accuracy=82.692
# >epoch=707, learning_rate=0.010, accuracy=82.692
# >epoch=708, learning_rate=0.010, accuracy=85.096
# >epoch=709, learning_rate=0.010, accuracy=81.731
# >epoch=710, learning_rate=0.010, accuracy=87.500
# >epoch=711, learning_rate=0.010, accuracy=84.135
# >epoch=712, learning_rate=0.010, accuracy=85.096
# >epoch=713, learning_rate=0.010, accuracy=85.096
# >epoch=714, learning_rate=0.010, accuracy=79.808
# >epoch=715, learning_rate=0.010, accuracy=83.654
# >epoch=716, learning_rate=0.010, accuracy=81.731
# >epoch=717, learning_rate=0.010, accuracy=85.577
# >epoch=718, learning_rate=0.010, accuracy=85.096
# >epoch=719, learning_rate=0.010, accuracy=79.808
# >epoch=720, learning_rate=0.010, accuracy=87.500
# >epoch=721, learning_rate=0.010, accuracy=84.135
# >epoch=722, learning_rate=0.010, accuracy=85.577
# >epoch=723, learning_rate=0.010, accuracy=83.654
# >epoch=724, learning_rate=0.010, accuracy=85.096
# >epoch=725, learning_rate=0.010, accuracy=83.173
# >epoch=726, learning_rate=0.010, accuracy=85.577
# >epoch=727, learning_rate=0.010, accuracy=83.173
# >epoch=728, learning_rate=0.010, accuracy=87.500
# >epoch=729, learning_rate=0.010, accuracy=81.250
# >epoch=730, learning_rate=0.010, accuracy=84.135
# >epoch=731, learning_rate=0.010, accuracy=83.173
# >epoch=732, learning_rate=0.010, accuracy=79.327
# >epoch=733, learning_rate=0.010, accuracy=84.615
# >epoch=734, learning_rate=0.010, accuracy=80.769
# >epoch=735, learning_rate=0.010, accuracy=86.538
# >epoch=736, learning_rate=0.010, accuracy=84.135
# >epoch=737, learning_rate=0.010, accuracy=81.731
# >epoch=738, learning_rate=0.010, accuracy=81.250
# >epoch=739, learning_rate=0.010, accuracy=86.538
# >epoch=740, learning_rate=0.010, accuracy=86.058
# >epoch=741, learning_rate=0.010, accuracy=86.058
# >epoch=742, learning_rate=0.010, accuracy=79.808
# >epoch=743, learning_rate=0.010, accuracy=85.096
# >epoch=744, learning_rate=0.010, accuracy=86.538
# >epoch=745, learning_rate=0.010, accuracy=80.288
# >epoch=746, learning_rate=0.010, accuracy=82.692
# >epoch=747, learning_rate=0.010, accuracy=84.615
# >epoch=748, learning_rate=0.010, accuracy=87.019
# >epoch=749, learning_rate=0.010, accuracy=87.019
# >epoch=750, learning_rate=0.010, accuracy=86.058
# >epoch=751, learning_rate=0.010, accuracy=86.538
# >epoch=752, learning_rate=0.010, accuracy=85.096
# >epoch=753, learning_rate=0.010, accuracy=86.538
# >epoch=754, learning_rate=0.010, accuracy=87.500
# >epoch=755, learning_rate=0.010, accuracy=82.212
# >epoch=756, learning_rate=0.010, accuracy=87.500
# >epoch=757, learning_rate=0.010, accuracy=84.135
# >epoch=758, learning_rate=0.010, accuracy=84.135
# >epoch=759, learning_rate=0.010, accuracy=86.538
# >epoch=760, learning_rate=0.010, accuracy=85.096
# >epoch=761, learning_rate=0.010, accuracy=82.212
# >epoch=762, learning_rate=0.010, accuracy=86.058
# >epoch=763, learning_rate=0.010, accuracy=85.577
# >epoch=764, learning_rate=0.010, accuracy=87.019
# >epoch=765, learning_rate=0.010, accuracy=87.019
# >epoch=766, learning_rate=0.010, accuracy=83.173
# >epoch=767, learning_rate=0.010, accuracy=84.135
# >epoch=768, learning_rate=0.010, accuracy=83.654
# >epoch=769, learning_rate=0.010, accuracy=85.096
# >epoch=770, learning_rate=0.010, accuracy=84.135
# >epoch=771, learning_rate=0.010, accuracy=82.692
# >epoch=772, learning_rate=0.010, accuracy=82.692
# >epoch=773, learning_rate=0.010, accuracy=86.538
# >epoch=774, learning_rate=0.010, accuracy=83.654
# >epoch=775, learning_rate=0.010, accuracy=84.135
# >epoch=776, learning_rate=0.010, accuracy=85.096
# >epoch=777, learning_rate=0.010, accuracy=87.981
# >epoch=778, learning_rate=0.010, accuracy=83.654
# >epoch=779, learning_rate=0.010, accuracy=84.615
# >epoch=780, learning_rate=0.010, accuracy=88.462
# >epoch=781, learning_rate=0.010, accuracy=85.577
# >epoch=782, learning_rate=0.010, accuracy=85.577
# >epoch=783, learning_rate=0.010, accuracy=85.096
# >epoch=784, learning_rate=0.010, accuracy=86.058
# >epoch=785, learning_rate=0.010, accuracy=87.019
# >epoch=786, learning_rate=0.010, accuracy=85.577
# >epoch=787, learning_rate=0.010, accuracy=87.019
# >epoch=788, learning_rate=0.010, accuracy=85.577
# >epoch=789, learning_rate=0.010, accuracy=87.500
# >epoch=790, learning_rate=0.010, accuracy=87.981
# >epoch=791, learning_rate=0.010, accuracy=82.692
# >epoch=792, learning_rate=0.010, accuracy=85.096
# >epoch=793, learning_rate=0.010, accuracy=87.019
# >epoch=794, learning_rate=0.010, accuracy=83.173
# >epoch=795, learning_rate=0.010, accuracy=84.135
# >epoch=796, learning_rate=0.010, accuracy=85.577
# >epoch=797, learning_rate=0.010, accuracy=84.615
# >epoch=798, learning_rate=0.010, accuracy=85.096
# >epoch=799, learning_rate=0.010, accuracy=81.731
# >epoch=800, learning_rate=0.010, accuracy=83.654
# >epoch=801, learning_rate=0.010, accuracy=85.096
# >epoch=802, learning_rate=0.010, accuracy=86.538
# >epoch=803, learning_rate=0.010, accuracy=86.538
# >epoch=804, learning_rate=0.010, accuracy=86.538
# >epoch=805, learning_rate=0.010, accuracy=84.615
# >epoch=806, learning_rate=0.010, accuracy=81.731
# >epoch=807, learning_rate=0.010, accuracy=80.769
# >epoch=808, learning_rate=0.010, accuracy=85.096
# >epoch=809, learning_rate=0.010, accuracy=84.615
# >epoch=810, learning_rate=0.010, accuracy=84.135
# >epoch=811, learning_rate=0.010, accuracy=86.058
# >epoch=812, learning_rate=0.010, accuracy=84.615
# >epoch=813, learning_rate=0.010, accuracy=87.981
# >epoch=814, learning_rate=0.010, accuracy=82.692
# >epoch=815, learning_rate=0.010, accuracy=85.577
# >epoch=816, learning_rate=0.010, accuracy=87.500
# >epoch=817, learning_rate=0.010, accuracy=87.019
# >epoch=818, learning_rate=0.010, accuracy=87.981
# >epoch=819, learning_rate=0.010, accuracy=88.942
# >epoch=820, learning_rate=0.010, accuracy=86.538
# >epoch=821, learning_rate=0.010, accuracy=86.538
# >epoch=822, learning_rate=0.010, accuracy=86.058
# >epoch=823, learning_rate=0.010, accuracy=84.615
# >epoch=824, learning_rate=0.010, accuracy=87.500
# >epoch=825, learning_rate=0.010, accuracy=80.288
# >epoch=826, learning_rate=0.010, accuracy=83.173
# >epoch=827, learning_rate=0.010, accuracy=82.692
# >epoch=828, learning_rate=0.010, accuracy=86.538
# >epoch=829, learning_rate=0.010, accuracy=85.577
# >epoch=830, learning_rate=0.010, accuracy=81.731
# >epoch=831, learning_rate=0.010, accuracy=85.577
# >epoch=832, learning_rate=0.010, accuracy=85.577
# >epoch=833, learning_rate=0.010, accuracy=87.500
# >epoch=834, learning_rate=0.010, accuracy=85.577
# >epoch=835, learning_rate=0.010, accuracy=87.981
# >epoch=836, learning_rate=0.010, accuracy=85.096
# >epoch=837, learning_rate=0.010, accuracy=78.365
# >epoch=838, learning_rate=0.010, accuracy=85.577
# >epoch=839, learning_rate=0.010, accuracy=83.173
# >epoch=840, learning_rate=0.010, accuracy=81.250
# >epoch=841, learning_rate=0.010, accuracy=84.615
# >epoch=842, learning_rate=0.010, accuracy=85.577
# >epoch=843, learning_rate=0.010, accuracy=85.577
# >epoch=844, learning_rate=0.010, accuracy=86.058
# >epoch=845, learning_rate=0.010, accuracy=87.981
# >epoch=846, learning_rate=0.010, accuracy=87.500
# >epoch=847, learning_rate=0.010, accuracy=86.058
# >epoch=848, learning_rate=0.010, accuracy=81.250
# >epoch=849, learning_rate=0.010, accuracy=81.731
# >epoch=850, learning_rate=0.010, accuracy=85.577
# >epoch=851, learning_rate=0.010, accuracy=83.654
# >epoch=852, learning_rate=0.010, accuracy=86.538
# >epoch=853, learning_rate=0.010, accuracy=85.577
# >epoch=854, learning_rate=0.010, accuracy=84.615
# >epoch=855, learning_rate=0.010, accuracy=86.538
# >epoch=856, learning_rate=0.010, accuracy=84.135
# >epoch=857, learning_rate=0.010, accuracy=86.058
# >epoch=858, learning_rate=0.010, accuracy=86.058
# >epoch=859, learning_rate=0.010, accuracy=84.135
# >epoch=860, learning_rate=0.010, accuracy=87.019
# >epoch=861, learning_rate=0.010, accuracy=82.692
# >epoch=862, learning_rate=0.010, accuracy=87.019
# >epoch=863, learning_rate=0.010, accuracy=86.538
# >epoch=864, learning_rate=0.010, accuracy=82.692
# >epoch=865, learning_rate=0.010, accuracy=85.577
# >epoch=866, learning_rate=0.010, accuracy=86.058
# >epoch=867, learning_rate=0.010, accuracy=85.577
# >epoch=868, learning_rate=0.010, accuracy=87.019
# >epoch=869, learning_rate=0.010, accuracy=85.096
# >epoch=870, learning_rate=0.010, accuracy=83.654
# >epoch=871, learning_rate=0.010, accuracy=87.500
# >epoch=872, learning_rate=0.010, accuracy=84.135
# >epoch=873, learning_rate=0.010, accuracy=84.135
# >epoch=874, learning_rate=0.010, accuracy=87.500
# >epoch=875, learning_rate=0.010, accuracy=83.654
# >epoch=876, learning_rate=0.010, accuracy=87.500
# >epoch=877, learning_rate=0.010, accuracy=87.500
# >epoch=878, learning_rate=0.010, accuracy=83.173
# >epoch=879, learning_rate=0.010, accuracy=83.654
# >epoch=880, learning_rate=0.010, accuracy=88.462
# >epoch=881, learning_rate=0.010, accuracy=88.942
# >epoch=882, learning_rate=0.010, accuracy=87.500
# >epoch=883, learning_rate=0.010, accuracy=88.942
# >epoch=884, learning_rate=0.010, accuracy=82.692
# >epoch=885, learning_rate=0.010, accuracy=86.538
# >epoch=886, learning_rate=0.010, accuracy=84.615
# >epoch=887, learning_rate=0.010, accuracy=83.654
# >epoch=888, learning_rate=0.010, accuracy=88.942
# >epoch=889, learning_rate=0.010, accuracy=83.654
# >epoch=890, learning_rate=0.010, accuracy=86.058
# >epoch=891, learning_rate=0.010, accuracy=82.212
# >epoch=892, learning_rate=0.010, accuracy=84.135
# >epoch=893, learning_rate=0.010, accuracy=85.577
# >epoch=894, learning_rate=0.010, accuracy=88.462
# >epoch=895, learning_rate=0.010, accuracy=83.654
# >epoch=896, learning_rate=0.010, accuracy=87.981
# >epoch=897, learning_rate=0.010, accuracy=88.942
# >epoch=898, learning_rate=0.010, accuracy=83.654
# >epoch=899, learning_rate=0.010, accuracy=88.462
# >epoch=900, learning_rate=0.010, accuracy=84.135
# >epoch=901, learning_rate=0.010, accuracy=84.135
# >epoch=902, learning_rate=0.010, accuracy=83.173
# >epoch=903, learning_rate=0.010, accuracy=86.058
# >epoch=904, learning_rate=0.010, accuracy=83.173
# >epoch=905, learning_rate=0.010, accuracy=85.096
# >epoch=906, learning_rate=0.010, accuracy=87.500
# >epoch=907, learning_rate=0.010, accuracy=87.500
# >epoch=908, learning_rate=0.010, accuracy=87.500
# >epoch=909, learning_rate=0.010, accuracy=84.135
# >epoch=910, learning_rate=0.010, accuracy=85.577
# >epoch=911, learning_rate=0.010, accuracy=85.096
# >epoch=912, learning_rate=0.010, accuracy=82.692
# >epoch=913, learning_rate=0.010, accuracy=84.135
# >epoch=914, learning_rate=0.010, accuracy=82.212
# >epoch=915, learning_rate=0.010, accuracy=85.577
# >epoch=916, learning_rate=0.010, accuracy=85.096
# >epoch=917, learning_rate=0.010, accuracy=88.462
# >epoch=918, learning_rate=0.010, accuracy=79.808
# >epoch=919, learning_rate=0.010, accuracy=86.538
# >epoch=920, learning_rate=0.010, accuracy=87.500
# >epoch=921, learning_rate=0.010, accuracy=83.173
# >epoch=922, learning_rate=0.010, accuracy=87.019
# >epoch=923, learning_rate=0.010, accuracy=87.981
# >epoch=924, learning_rate=0.010, accuracy=82.692
# >epoch=925, learning_rate=0.010, accuracy=82.692
# >epoch=926, learning_rate=0.010, accuracy=87.500
# >epoch=927, learning_rate=0.010, accuracy=84.615
# >epoch=928, learning_rate=0.010, accuracy=86.058
# >epoch=929, learning_rate=0.010, accuracy=86.058
# >epoch=930, learning_rate=0.010, accuracy=86.058
# >epoch=931, learning_rate=0.010, accuracy=86.538
# >epoch=932, learning_rate=0.010, accuracy=84.135
# >epoch=933, learning_rate=0.010, accuracy=84.615
# >epoch=934, learning_rate=0.010, accuracy=87.500
# >epoch=935, learning_rate=0.010, accuracy=85.096
# >epoch=936, learning_rate=0.010, accuracy=85.577
# >epoch=937, learning_rate=0.010, accuracy=84.135
# >epoch=938, learning_rate=0.010, accuracy=85.096
# >epoch=939, learning_rate=0.010, accuracy=82.692
# >epoch=940, learning_rate=0.010, accuracy=83.173
# >epoch=941, learning_rate=0.010, accuracy=82.692
# >epoch=942, learning_rate=0.010, accuracy=83.654
# >epoch=943, learning_rate=0.010, accuracy=87.500
# >epoch=944, learning_rate=0.010, accuracy=85.096
# >epoch=945, learning_rate=0.010, accuracy=87.981
# >epoch=946, learning_rate=0.010, accuracy=87.019
# >epoch=947, learning_rate=0.010, accuracy=85.577
# >epoch=948, learning_rate=0.010, accuracy=87.019
# >epoch=949, learning_rate=0.010, accuracy=86.538
# >epoch=950, learning_rate=0.010, accuracy=85.096
# >epoch=951, learning_rate=0.010, accuracy=86.538
# >epoch=952, learning_rate=0.010, accuracy=87.500
# >epoch=953, learning_rate=0.010, accuracy=84.615
# >epoch=954, learning_rate=0.010, accuracy=80.288
# >epoch=955, learning_rate=0.010, accuracy=85.096
# >epoch=956, learning_rate=0.010, accuracy=86.058
# >epoch=957, learning_rate=0.010, accuracy=85.577
# >epoch=958, learning_rate=0.010, accuracy=87.500
# >epoch=959, learning_rate=0.010, accuracy=86.058
# >epoch=960, learning_rate=0.010, accuracy=84.135
# >epoch=961, learning_rate=0.010, accuracy=88.942
# >epoch=962, learning_rate=0.010, accuracy=87.981
# >epoch=963, learning_rate=0.010, accuracy=88.462
# >epoch=964, learning_rate=0.010, accuracy=86.538
# >epoch=965, learning_rate=0.010, accuracy=87.500
# >epoch=966, learning_rate=0.010, accuracy=80.769
# >epoch=967, learning_rate=0.010, accuracy=87.981
# >epoch=968, learning_rate=0.010, accuracy=87.981
# >epoch=969, learning_rate=0.010, accuracy=89.423
# >epoch=970, learning_rate=0.010, accuracy=83.654
# >epoch=971, learning_rate=0.010, accuracy=83.654
# >epoch=972, learning_rate=0.010, accuracy=82.692
# >epoch=973, learning_rate=0.010, accuracy=85.577
# >epoch=974, learning_rate=0.010, accuracy=87.981
# >epoch=975, learning_rate=0.010, accuracy=81.731
# >epoch=976, learning_rate=0.010, accuracy=81.731
# >epoch=977, learning_rate=0.010, accuracy=86.058
# >epoch=978, learning_rate=0.010, accuracy=81.250
# >epoch=979, learning_rate=0.010, accuracy=82.692
# >epoch=980, learning_rate=0.010, accuracy=88.942
# ...
# >epoch=7682, learning_rate=0.010, accuracy=88.462
# >epoch=7683, learning_rate=0.010, accuracy=82.692
# >epoch=7684, learning_rate=0.010, accuracy=84.615
# >epoch=7685, learning_rate=0.010, accuracy=83.654
# >epoch=7686, learning_rate=0.010, accuracy=85.096
# >epoch=7687, learning_rate=0.010, accuracy=85.096
# >epoch=7688, learning_rate=0.010, accuracy=79.808
# >epoch=7689, learning_rate=0.010, accuracy=87.019
# >epoch=7690, learning_rate=0.010, accuracy=86.058
# >epoch=7691, learning_rate=0.010, accuracy=79.808
# >epoch=7692, learning_rate=0.010, accuracy=80.769
# >epoch=7693, learning_rate=0.010, accuracy=84.615
# >epoch=7694, learning_rate=0.010, accuracy=83.654
# >epoch=7695, learning_rate=0.010, accuracy=90.385
# >epoch=7696, learning_rate=0.010, accuracy=79.808
# >epoch=7697, learning_rate=0.010, accuracy=84.615
# >epoch=7698, learning_rate=0.010, accuracy=89.904
# >epoch=7699, learning_rate=0.010, accuracy=90.385
# >epoch=7700, learning_rate=0.010, accuracy=89.904
# >epoch=7701, learning_rate=0.010, accuracy=90.385
# >epoch=7702, learning_rate=0.010, accuracy=91.827
# >epoch=7703, learning_rate=0.010, accuracy=90.865
# >epoch=7704, learning_rate=0.010, accuracy=88.462
# >epoch=7705, learning_rate=0.010, accuracy=87.019
# >epoch=7706, learning_rate=0.010, accuracy=86.058
# >epoch=7707, learning_rate=0.010, accuracy=84.135
# >epoch=7708, learning_rate=0.010, accuracy=87.019
# >epoch=7709, learning_rate=0.010, accuracy=87.981
# >epoch=7710, learning_rate=0.010, accuracy=90.385
# >epoch=7711, learning_rate=0.010, accuracy=90.385
# >epoch=7712, learning_rate=0.010, accuracy=89.423
# >epoch=7713, learning_rate=0.010, accuracy=88.942
# >epoch=7714, learning_rate=0.010, accuracy=87.019
# >epoch=7715, learning_rate=0.010, accuracy=89.423
# >epoch=7716, learning_rate=0.010, accuracy=89.904
# >epoch=7717, learning_rate=0.010, accuracy=86.538
# >epoch=7718, learning_rate=0.010, accuracy=86.538
# >epoch=7719, learning_rate=0.010, accuracy=90.385
# >epoch=7720, learning_rate=0.010, accuracy=90.385
# >epoch=7721, learning_rate=0.010, accuracy=90.865
# >epoch=7722, learning_rate=0.010, accuracy=90.865
# >epoch=7723, learning_rate=0.010, accuracy=83.654
# >epoch=7724, learning_rate=0.010, accuracy=90.385
# >epoch=7725, learning_rate=0.010, accuracy=90.385
# >epoch=7726, learning_rate=0.010, accuracy=90.865
# >epoch=7727, learning_rate=0.010, accuracy=83.173
# >epoch=7728, learning_rate=0.010, accuracy=89.423
# >epoch=7729, learning_rate=0.010, accuracy=90.385
# >epoch=7730, learning_rate=0.010, accuracy=91.827
# >epoch=7731, learning_rate=0.010, accuracy=82.692
# >epoch=7732, learning_rate=0.010, accuracy=90.385
# >epoch=7733, learning_rate=0.010, accuracy=87.981
# >epoch=7734, learning_rate=0.010, accuracy=85.577
# >epoch=7735, learning_rate=0.010, accuracy=84.135
# >epoch=7736, learning_rate=0.010, accuracy=82.212
# >epoch=7737, learning_rate=0.010, accuracy=91.346
# >epoch=7738, learning_rate=0.010, accuracy=86.538
# >epoch=7739, learning_rate=0.010, accuracy=87.019
# >epoch=7740, learning_rate=0.010, accuracy=86.538
# >epoch=7741, learning_rate=0.010, accuracy=88.462
# >epoch=7742, learning_rate=0.010, accuracy=85.577
# >epoch=7743, learning_rate=0.010, accuracy=82.692
# >epoch=7744, learning_rate=0.010, accuracy=89.904
# >epoch=7745, learning_rate=0.010, accuracy=89.904
# >epoch=7746, learning_rate=0.010, accuracy=84.135
# >epoch=7747, learning_rate=0.010, accuracy=85.096
# >epoch=7748, learning_rate=0.010, accuracy=87.019
# >epoch=7749, learning_rate=0.010, accuracy=87.019
# >epoch=7750, learning_rate=0.010, accuracy=83.173
# >epoch=7751, learning_rate=0.010, accuracy=84.615
# >epoch=7752, learning_rate=0.010, accuracy=90.385
# >epoch=7753, learning_rate=0.010, accuracy=89.423
# >epoch=7754, learning_rate=0.010, accuracy=87.981
# >epoch=7755, learning_rate=0.010, accuracy=90.385
# >epoch=7756, learning_rate=0.010, accuracy=90.865
# >epoch=7757, learning_rate=0.010, accuracy=91.346
# >epoch=7758, learning_rate=0.010, accuracy=90.865
# >epoch=7759, learning_rate=0.010, accuracy=89.904
# >epoch=7760, learning_rate=0.010, accuracy=90.385
# >epoch=7761, learning_rate=0.010, accuracy=91.346
# >epoch=7762, learning_rate=0.010, accuracy=89.904
# >epoch=7763, learning_rate=0.010, accuracy=89.423
# >epoch=7764, learning_rate=0.010, accuracy=89.904
# >epoch=7765, learning_rate=0.010, accuracy=90.385
# >epoch=7766, learning_rate=0.010, accuracy=89.904
# >epoch=7767, learning_rate=0.010, accuracy=88.942
# >epoch=7768, learning_rate=0.010, accuracy=87.019
# >epoch=7769, learning_rate=0.010, accuracy=84.615
# >epoch=7770, learning_rate=0.010, accuracy=87.500
# >epoch=7771, learning_rate=0.010, accuracy=88.462
# >epoch=7772, learning_rate=0.010, accuracy=88.462
# >epoch=7773, learning_rate=0.010, accuracy=89.904
# >epoch=7774, learning_rate=0.010, accuracy=84.135
# >epoch=7775, learning_rate=0.010, accuracy=90.865
# >epoch=7776, learning_rate=0.010, accuracy=87.019
# >epoch=7777, learning_rate=0.010, accuracy=85.577
# >epoch=7778, learning_rate=0.010, accuracy=84.135
# >epoch=7779, learning_rate=0.010, accuracy=81.250
# >epoch=7780, learning_rate=0.010, accuracy=83.173
# >epoch=7781, learning_rate=0.010, accuracy=90.865
# >epoch=7782, learning_rate=0.010, accuracy=86.538
# >epoch=7783, learning_rate=0.010, accuracy=88.462
# >epoch=7784, learning_rate=0.010, accuracy=86.058
# >epoch=7785, learning_rate=0.010, accuracy=87.981
# >epoch=7786, learning_rate=0.010, accuracy=84.615
# >epoch=7787, learning_rate=0.010, accuracy=81.250
# >epoch=7788, learning_rate=0.010, accuracy=81.250
# >epoch=7789, learning_rate=0.010, accuracy=90.865
# >epoch=7790, learning_rate=0.010, accuracy=90.865
# >epoch=7791, learning_rate=0.010, accuracy=89.904
# >epoch=7792, learning_rate=0.010, accuracy=89.423
# >epoch=7793, learning_rate=0.010, accuracy=90.385
# >epoch=7794, learning_rate=0.010, accuracy=81.250
# >epoch=7795, learning_rate=0.010, accuracy=79.808
# >epoch=7796, learning_rate=0.010, accuracy=91.827
# >epoch=7797, learning_rate=0.010, accuracy=79.327
# >epoch=7798, learning_rate=0.010, accuracy=91.346
# >epoch=7799, learning_rate=0.010, accuracy=91.346
# >epoch=7800, learning_rate=0.010, accuracy=88.942
# >epoch=7801, learning_rate=0.010, accuracy=81.731
# >epoch=7802, learning_rate=0.010, accuracy=79.327
# >epoch=7803, learning_rate=0.010, accuracy=89.423
# >epoch=7804, learning_rate=0.010, accuracy=82.212
# >epoch=7805, learning_rate=0.010, accuracy=90.385
# >epoch=7806, learning_rate=0.010, accuracy=89.423
# >epoch=7807, learning_rate=0.010, accuracy=87.019
# >epoch=7808, learning_rate=0.010, accuracy=83.173
# >epoch=7809, learning_rate=0.010, accuracy=79.327
# >epoch=7810, learning_rate=0.010, accuracy=90.385
# >epoch=7811, learning_rate=0.010, accuracy=86.538
# >epoch=7812, learning_rate=0.010, accuracy=80.769
# >epoch=7813, learning_rate=0.010, accuracy=89.423
# >epoch=7814, learning_rate=0.010, accuracy=87.019
# >epoch=7815, learning_rate=0.010, accuracy=85.577
# >epoch=7816, learning_rate=0.010, accuracy=86.538
# >epoch=7817, learning_rate=0.010, accuracy=80.769
# >epoch=7818, learning_rate=0.010, accuracy=90.385
# >epoch=7819, learning_rate=0.010, accuracy=89.423
# >epoch=7820, learning_rate=0.010, accuracy=87.500
# >epoch=7821, learning_rate=0.010, accuracy=90.385
# >epoch=7822, learning_rate=0.010, accuracy=82.692
# >epoch=7823, learning_rate=0.010, accuracy=83.654
# >epoch=7824, learning_rate=0.010, accuracy=79.327
# >epoch=7825, learning_rate=0.010, accuracy=91.346
# >epoch=7826, learning_rate=0.010, accuracy=84.135
# >epoch=7827, learning_rate=0.010, accuracy=86.538
# >epoch=7828, learning_rate=0.010, accuracy=88.942
# >epoch=7829, learning_rate=0.010, accuracy=90.385
# >epoch=7830, learning_rate=0.010, accuracy=91.346
# >epoch=7831, learning_rate=0.010, accuracy=90.865
# >epoch=7832, learning_rate=0.010, accuracy=82.212
# >epoch=7833, learning_rate=0.010, accuracy=82.692
# >epoch=7834, learning_rate=0.010, accuracy=81.250
# >epoch=7835, learning_rate=0.010, accuracy=88.942
# >epoch=7836, learning_rate=0.010, accuracy=84.135
# >epoch=7837, learning_rate=0.010, accuracy=89.423
# >epoch=7838, learning_rate=0.010, accuracy=88.942
# >epoch=7839, learning_rate=0.010, accuracy=87.019
# >epoch=7840, learning_rate=0.010, accuracy=81.250
# >epoch=7841, learning_rate=0.010, accuracy=90.385
# >epoch=7842, learning_rate=0.010, accuracy=80.288
# >epoch=7843, learning_rate=0.010, accuracy=87.981
# >epoch=7844, learning_rate=0.010, accuracy=83.173
# >epoch=7845, learning_rate=0.010, accuracy=82.212
# >epoch=7846, learning_rate=0.010, accuracy=88.462
# >epoch=7847, learning_rate=0.010, accuracy=90.385
# >epoch=7848, learning_rate=0.010, accuracy=83.654
# >epoch=7849, learning_rate=0.010, accuracy=89.904
# >epoch=7850, learning_rate=0.010, accuracy=89.904
# >epoch=7851, learning_rate=0.010, accuracy=89.423
# >epoch=7852, learning_rate=0.010, accuracy=82.692
# >epoch=7853, learning_rate=0.010, accuracy=80.288
# >epoch=7854, learning_rate=0.010, accuracy=85.577
# >epoch=7855, learning_rate=0.010, accuracy=89.423
# >epoch=7856, learning_rate=0.010, accuracy=91.346
# >epoch=7857, learning_rate=0.010, accuracy=79.327
# >epoch=7858, learning_rate=0.010, accuracy=90.385
# >epoch=7859, learning_rate=0.010, accuracy=81.250
# >epoch=7860, learning_rate=0.010, accuracy=91.346
# >epoch=7861, learning_rate=0.010, accuracy=90.385
# >epoch=7862, learning_rate=0.010, accuracy=90.385
# >epoch=7863, learning_rate=0.010, accuracy=88.942
# >epoch=7864, learning_rate=0.010, accuracy=89.904
# >epoch=7865, learning_rate=0.010, accuracy=81.250
# >epoch=7866, learning_rate=0.010, accuracy=84.615
# >epoch=7867, learning_rate=0.010, accuracy=89.904
# >epoch=7868, learning_rate=0.010, accuracy=89.904
# >epoch=7869, learning_rate=0.010, accuracy=84.135
# >epoch=7870, learning_rate=0.010, accuracy=86.058
# >epoch=7871, learning_rate=0.010, accuracy=89.423
# >epoch=7872, learning_rate=0.010, accuracy=88.942
# >epoch=7873, learning_rate=0.010, accuracy=89.904
# >epoch=7874, learning_rate=0.010, accuracy=84.135
# >epoch=7875, learning_rate=0.010, accuracy=89.904
# >epoch=7876, learning_rate=0.010, accuracy=78.846
# >epoch=7877, learning_rate=0.010, accuracy=80.288
# >epoch=7878, learning_rate=0.010, accuracy=88.462
# >epoch=7879, learning_rate=0.010, accuracy=87.500
# >epoch=7880, learning_rate=0.010, accuracy=84.135
# >epoch=7881, learning_rate=0.010, accuracy=81.250
# >epoch=7882, learning_rate=0.010, accuracy=80.769
# >epoch=7883, learning_rate=0.010, accuracy=90.865
# >epoch=7884, learning_rate=0.010, accuracy=89.423
# >epoch=7885, learning_rate=0.010, accuracy=79.327
# >epoch=7886, learning_rate=0.010, accuracy=89.904
# >epoch=7887, learning_rate=0.010, accuracy=90.865
# >epoch=7888, learning_rate=0.010, accuracy=84.615
# >epoch=7889, learning_rate=0.010, accuracy=89.423
# >epoch=7890, learning_rate=0.010, accuracy=89.423
# >epoch=7891, learning_rate=0.010, accuracy=82.212
# >epoch=7892, learning_rate=0.010, accuracy=90.865
# >epoch=7893, learning_rate=0.010, accuracy=85.096
# >epoch=7894, learning_rate=0.010, accuracy=87.500
# >epoch=7895, learning_rate=0.010, accuracy=87.019
# >epoch=7896, learning_rate=0.010, accuracy=90.385
# >epoch=7897, learning_rate=0.010, accuracy=89.423
# >epoch=7898, learning_rate=0.010, accuracy=89.904
# >epoch=7899, learning_rate=0.010, accuracy=90.385
# >epoch=7900, learning_rate=0.010, accuracy=89.423
# >epoch=7901, learning_rate=0.010, accuracy=89.904
# >epoch=7902, learning_rate=0.010, accuracy=85.096
# >epoch=7903, learning_rate=0.010, accuracy=80.769
# >epoch=7904, learning_rate=0.010, accuracy=84.615
# >epoch=7905, learning_rate=0.010, accuracy=89.904
# >epoch=7906, learning_rate=0.010, accuracy=89.423
# >epoch=7907, learning_rate=0.010, accuracy=84.615
# >epoch=7908, learning_rate=0.010, accuracy=89.423
# >epoch=7909, learning_rate=0.010, accuracy=89.904
# >epoch=7910, learning_rate=0.010, accuracy=90.385
# >epoch=7911, learning_rate=0.010, accuracy=79.808
# >epoch=7912, learning_rate=0.010, accuracy=86.058
# >epoch=7913, learning_rate=0.010, accuracy=85.096
# >epoch=7914, learning_rate=0.010, accuracy=88.942
# >epoch=7915, learning_rate=0.010, accuracy=88.942
# >epoch=7916, learning_rate=0.010, accuracy=87.019
# >epoch=7917, learning_rate=0.010, accuracy=84.615
# >epoch=7918, learning_rate=0.010, accuracy=83.173
# >epoch=7919, learning_rate=0.010, accuracy=89.423
# >epoch=7920, learning_rate=0.010, accuracy=89.904
# >epoch=7921, learning_rate=0.010, accuracy=90.385
# >epoch=7922, learning_rate=0.010, accuracy=84.615
# >epoch=7923, learning_rate=0.010, accuracy=80.769
# >epoch=7924, learning_rate=0.010, accuracy=83.173
# >epoch=7925, learning_rate=0.010, accuracy=86.538
# >epoch=7926, learning_rate=0.010, accuracy=80.288
# >epoch=7927, learning_rate=0.010, accuracy=90.865
# >epoch=7928, learning_rate=0.010, accuracy=83.173
# >epoch=7929, learning_rate=0.010, accuracy=90.385
# >epoch=7930, learning_rate=0.010, accuracy=85.577
# >epoch=7931, learning_rate=0.010, accuracy=85.577
# >epoch=7932, learning_rate=0.010, accuracy=88.462
# >epoch=7933, learning_rate=0.010, accuracy=89.904
# >epoch=7934, learning_rate=0.010, accuracy=89.904
# >epoch=7935, learning_rate=0.010, accuracy=78.846
# >epoch=7936, learning_rate=0.010, accuracy=87.981
# >epoch=7937, learning_rate=0.010, accuracy=89.904
# >epoch=7938, learning_rate=0.010, accuracy=81.250
# >epoch=7939, learning_rate=0.010, accuracy=82.212
# >epoch=7940, learning_rate=0.010, accuracy=89.904
# >epoch=7941, learning_rate=0.010, accuracy=87.019
# >epoch=7942, learning_rate=0.010, accuracy=88.462
# >epoch=7943, learning_rate=0.010, accuracy=89.904
# >epoch=7944, learning_rate=0.010, accuracy=85.096
# >epoch=7945, learning_rate=0.010, accuracy=86.538
# >epoch=7946, learning_rate=0.010, accuracy=81.731
# >epoch=7947, learning_rate=0.010, accuracy=89.904
# >epoch=7948, learning_rate=0.010, accuracy=89.423
# >epoch=7949, learning_rate=0.010, accuracy=80.288
# >epoch=7950, learning_rate=0.010, accuracy=85.096
# >epoch=7951, learning_rate=0.010, accuracy=89.423
# >epoch=7952, learning_rate=0.010, accuracy=86.058
# >epoch=7953, learning_rate=0.010, accuracy=81.731
# >epoch=7954, learning_rate=0.010, accuracy=90.385
# >epoch=7955, learning_rate=0.010, accuracy=89.904
# >epoch=7956, learning_rate=0.010, accuracy=89.423
# >epoch=7957, learning_rate=0.010, accuracy=86.538
# >epoch=7958, learning_rate=0.010, accuracy=81.731
# >epoch=7959, learning_rate=0.010, accuracy=89.423
# >epoch=7960, learning_rate=0.010, accuracy=85.577
# >epoch=7961, learning_rate=0.010, accuracy=87.019
# >epoch=7962, learning_rate=0.010, accuracy=84.135
# >epoch=7963, learning_rate=0.010, accuracy=80.288
# >epoch=7964, learning_rate=0.010, accuracy=89.904
# >epoch=7965, learning_rate=0.010, accuracy=90.385
# >epoch=7966, learning_rate=0.010, accuracy=91.346
# >epoch=7967, learning_rate=0.010, accuracy=86.538
# >epoch=7968, learning_rate=0.010, accuracy=80.769
# >epoch=7969, learning_rate=0.010, accuracy=90.385
# >epoch=7970, learning_rate=0.010, accuracy=83.654
# >epoch=7971, learning_rate=0.010, accuracy=79.327
# >epoch=7972, learning_rate=0.010, accuracy=87.981
# >epoch=7973, learning_rate=0.010, accuracy=85.096
# >epoch=7974, learning_rate=0.010, accuracy=87.981
# >epoch=7975, learning_rate=0.010, accuracy=88.942
# >epoch=7976, learning_rate=0.010, accuracy=84.615
# >epoch=7977, learning_rate=0.010, accuracy=84.135
# >epoch=7978, learning_rate=0.010, accuracy=84.135
# >epoch=7979, learning_rate=0.010, accuracy=89.423
# >epoch=7980, learning_rate=0.010, accuracy=88.942
# >epoch=7981, learning_rate=0.010, accuracy=85.096
# >epoch=7982, learning_rate=0.010, accuracy=84.135
# >epoch=7983, learning_rate=0.010, accuracy=83.654
# >epoch=7984, learning_rate=0.010, accuracy=90.385
# >epoch=7985, learning_rate=0.010, accuracy=90.385
# >epoch=7986, learning_rate=0.010, accuracy=81.250
# >epoch=7987, learning_rate=0.010, accuracy=89.423
# >epoch=7988, learning_rate=0.010, accuracy=81.731
# >epoch=7989, learning_rate=0.010, accuracy=89.904
# >epoch=7990, learning_rate=0.010, accuracy=88.942
# >epoch=7991, learning_rate=0.010, accuracy=90.865
# >epoch=7992, learning_rate=0.010, accuracy=85.577
# >epoch=7993, learning_rate=0.010, accuracy=86.058
# >epoch=7994, learning_rate=0.010, accuracy=89.904
# >epoch=7995, learning_rate=0.010, accuracy=87.981
# >epoch=7996, learning_rate=0.010, accuracy=91.827
# >epoch=7997, learning_rate=0.010, accuracy=80.769
# >epoch=7998, learning_rate=0.010, accuracy=79.808
# >epoch=7999, learning_rate=0.010, accuracy=91.346
# >epoch=8000, learning_rate=0.010, accuracy=91.827
# training complete
# final accuracy: 91.827

# %%
trainer_1 = list([neuron.b, *neuron.w])
save_pkl('sonar_bw.pkl', trainer_1)

with open('sonar_bw.pkl', 'rb') as f:
    loadedneuron = pkl.load(f)
    
len(loadedneuron)
# Out:
# 61

# %%
print(loadedneuron)
# Out:
# [-0.978768498557326, 3.3511545166153662, -1.4401817854123216, -3.15837383296481, 3.510885284268141, -0.17467554421393425, 0.7279040901577367, -2.2551317237721578, 0.46988140204224665, 0.6980620599025197, -0.8567161438607757, 1.1076498314120176, 0.6956614504612143, 0.18441465402360888, -0.6694051504305462, 0.9798909491287509, -1.066429878870627, -0.8806606391473315, 0.947173891077489, -0.5479527878834912, 1.3028039174048376, -1.629711820188371, 1.9678986684487436, -1.3659706026068985, 1.4383521576802103, -0.10550921841221099, -0.8948449120448982, 0.916736904168914, -0.6067457670631093, 0.062158610489854375, 1.2118689132115077, -1.8794546966285939, 0.7402139603007399, 0.7608006802307903, -1.3428163045871864, 1.1978454477722733, -1.2258937679076958, 0.12087913429223239, -0.12019397524033579, 1.0844865281879197, -1.5437453019031795, 0.464725864988818, 0.11815398964919208, -0.1388890395663341, 0.5389676260167825, 0.3152409889327042, 0.7548051863300667, -1.6134666306743164, 2.8367543751586566, 4.050049615273538, -7.091239769809339, 4.36709262059415, 3.4582179470992784, 4.415937414894028, 3.005637258163, 0.27756066531105256, -0.44040100536841975, -2.9828706698847585, 1.9059975055027527, 2.4643523706675, 2.344978628731176]
